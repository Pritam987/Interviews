# %%
import re
def print_vowel_runs_re(text):
    print(*re.findall(r'[aeiouAEIOU]+', text),sep='\n')

# %%
# Test cases
print("--- Test Case 1 ---")
print_vowel_runs_re("beautiful automobile")
# Out:
# --- Test Case 1 ---
# eau
# i
# u
# au
# o
# o
# i
# e
